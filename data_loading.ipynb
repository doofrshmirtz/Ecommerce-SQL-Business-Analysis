# %%
# !pip install psycopg2==2.9.3 --only-binary :all:
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 14.3 MB/s eta 0:00:00
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
import psycopg2
print(psycopg2.__version__)
# Out:
# 2.9.3 (dt dec pq3 ext lo64)

# %%
# !python -m pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached sqlalchemy-2.0.48-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
# ...
# Using cached sqlalchemy-2.0.48-cp38-cp38-win_amd64.whl (2.1 MB)
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import os

# %%
password = quote_plus("N@nami1998")
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/ecommerce_analysis')
#Test connection
with engine.connect() as conn :
    print("Connected successfully!")
# Out:
# Connected successfully!

# %%
data_path = r"C:\Data analyst projects\ecommerce analysis\archive (3)"
files = {
    'orders':      'olist_orders_dataset.csv',
    'customers':   'olist_customers_dataset.csv',
    'products':    'olist_products_dataset.csv',
    'payments':    'olist_order_payments_dataset.csv',
    'order_items': 'olist_order_items_dataset.csv',
    'sellers':     'olist_sellers_dataset.csv',
    'reviews':     'olist_order_reviews_dataset.csv' 
}

for table_name, file_name in files.items():
    file_path = os.path.join(data_path, file_name)
    df = pd.read_csv(file_path)
    df.to_sql(table_name, engine, if_exists='replace', index = False)
    print(f"Loaded {table_name} - {len(df)} rows")
# Out:
# Loaded orders - 99441 rows
# Loaded customers - 99441 rows
# Loaded products - 32951 rows
# Loaded payments - 103886 rows
# Loaded order_items - 112650 rows
# Loaded sellers - 3095 rows
# Loaded reviews - 99224 rows
